# %%
# %matplotlib inline
from opensimplex import OpenSimplex
import matplotlib.pyplot as plt
from autoencoder import loadDecoder
import numpy as np

decoder = loadDecoder()

# %%
LatentRepresentation = np.random.random((1, 16, 16, 1))
outt = decoder.predict(LatentRepresentation)
plt.figure(1)
plt.imshow(LatentRepresentation.reshape((16, 16)), cmap='gray')
plt.figure(2)
plt.imshow(outt[0].reshape((256, 256)), cmap='gray')
